# %%
import cv2

# %%
import cv2

# Load the image
image = cv2.imread('viratkohli.jpeg')

# Check if the image was loaded successfully
if image is None:
    print("Error: Could not load image.")
else:
    # Get height and width
    h, w = image.shape[:2]
    print("h={}, w={}".format(h, w))

    # Display the image
    cv2.imshow('Image Window', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# h=225, w=225

# %%
h=800
w=500
cv2.resize(image,(h,w))
print("h={}, w={}".format(h, w))
cv2.imshow('Image Window', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# h=800, w=500

# %%
cv2.rectangle(image,(80,120),(70,100),(233,0,231),3)
cv2.imshow("Image with Rectangle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
b=cv2.imread("bollywood.jpeg")
cv2.putText(b,'OpenCV Demo', (120, 50),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 0),2)
cv2.imshow('Image Window', b)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1=cv2.imread("sunnyleone.jpeg",cv2.IMREAD_GRAYSCALE)
cv2.imshow('Image Window', img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)

# %%
img2=cv2.imread("viratkohli.jpeg",cv2.IMREAD_COLOR)
image1 = cv2.copyMakeBorder(img2, 10, 10, 10, 10, cv2.BORDER_CONSTANT, None, value = 0) 
cv2.imshow("window",image1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img2.shape
# Out:
# (225, 225, 3)

# %%
# Import the necessary Libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
 
# Read image from disk.
img = cv2.imread('viratkohli.jpeg')
# Convert BGR image to RGB
image_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Apply Canny edge detection
edges = cv2.Canny(image= image_rgb, threshold1=100, threshold2=700)

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(7, 4))

# Plot the original image
axs[0].imshow(image_rgb)
axs[0].set_title('Original Image')

# Plot the blurred image
axs[1].imshow(edges)
axs[1].set_title('Image edges')

# Remove ticks from the subplots
for ax in axs:
    ax.set_xticks([])
    ax.set_yticks([])

# Display the subplots
plt.tight_layout()
plt.show()
