# %%
import cv2

# %%
img = cv2.imread('viratkohli.jpeg')
dimensions = img.shape
print(dimensions)
# Out:
# (225, 225, 3)

# %%
virat=cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
resized = cv2.resize(img, (500, 500))

# %%
print(resized.shape)
# Out:
# (500, 500, 3)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image = cv2.imread('viratkohli.jpeg')
cv2.imshow("Image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
gray = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
hist = cv2.calcHist([gray], [0], None, [256], [0, 256])

# Plot the histogram
plt.figure()
plt.title("Grayscale Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.plot(hist)
plt.xlim([0, 256])
plt.show()

# %%
# Importing the OpenCV library
import cv2
# Reading the image using imread() function
image = cv2.imread('viratkohli.jpeg')

# Extracting the height and width of an image
h, w = image.shape[:2]
# Displaying the height and width
print("Height = {}, Width = {}".format(h, w))
# Out:
# Height = 225, Width = 225

# %%
# Extracting RGB values.
# Here we have randomly chosen a pixel
# by passing in 100, 100 for height and width.
(B, G, R) = image[100, 100]

# Displaying the pixel values
print("R = {}, G = {}, B = {}".format(R, G, B))

# We can also pass the channel to extract
# the value for a specific channel
B = image[100, 100, 0]
print("B = {}".format(B))
# Out:
# R = 43, G = 27, B = 76
# B = 76

# %%
# We will calculate the region of interest
# by slicing the pixels of the image
roi = image[100 : 500, 200 : 700]
cv2.imshow("ROI", roi)
cv2.waitKey(0)
# Out:
# -1

# %%
# resize() function takes 2 parameters,
# the image and the dimensions
resize = cv2.resize(image, (500, 500))
cv2.imshow("Resized Image", resize)
cv2.waitKey(0)
# Out:
# -1

# %%
# Calculating the ratio
ratio = 800 / w

# Creating a tuple containing width and height
dim = (800, int(h * ratio))

# Resizing the image
resize_aspect = cv2.resize(image, dim)
cv2.imshow("Resized Image", resize_aspect)
cv2.waitKey(0)
# Out:
# -1

# %%
ratio = 800 / w
dim = (800, int(h * ratio))
resize_aspect = cv2.resize(image, dim)
rectangle = cv2.rectangle(output, (1500, 900),
                        (600, 400), (255, 0, 0), 4) # Increased thickness
cv2.imshow('Image with Text', resize_aspect)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
ratio = 800 / w
dim = (800, int(h * ratio))
resize_aspect = cv2.resize(image, dim)
cv2.putText(resize_aspect, 'OpenCV Demo', (50, 100),  # Adjusted position
            cv2.FONT_HERSHEY_SIMPLEX, 2, (255, 0, 0), 5)  # Increased thickness
cv2.imshow('Image with Text', resize_aspect)
cv2.waitKey(0)
cv2.destroyAllWindows()
